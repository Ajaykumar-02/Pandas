# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Create a DataFrame

# %% [markdown]
# In pandas we Create DateFrame using Dict and list.

# %%
#Dict
data = {
    "Name":['John','Anna','Peter','Linda'],
    "Age":[28,34,29,42],
    "City":['New York','Paris','Berlin','London'],
    'Salary':[65000,7000,62000,85000]   
}
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#list
data_list=[
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',7000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',85000]
]

col=['Name','Age','City','Salary']
df2=pd.DataFrame(data_list,columns=col)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # Selection and Indexing of Columns

# %%
 df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df['Name'] # For targeting single Column
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df[['Name','City']] # For targeting multiple Column
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new Column

# %%
df2['Designation']=["Dr.","Eng.","Dr.","Eng."]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000         Dr.
# 1   Anna   34     Paris    7000        Eng.
# 2  Peter   29    Berlin   62000         Dr.
# 3  Linda   42    London   85000        Eng.

# %% [markdown]
# Removing Column

# %%
df2.drop("Designation",axis=1) #like for snapshot(view)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000         Dr.
# 1   Anna   34     Paris    7000        Eng.
# 2  Peter   29    Berlin   62000         Dr.
# 3  Linda   42    London   85000        Eng.

# %%
df2.drop("Designation",axis=1,inplace=True) # For forever delete

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.drop(["Name","Age"],axis=1) #for multiple
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris    7000
# 2    Berlin   62000
# 3    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris    7000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0] #loc means location
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,3]] # for selecting multiple rows
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 3  Linda   42    London   85000

# %%
df2.iloc[2] #indexing/Lables location like :2
# Out:
# Name       Peter
# Age           29
# City      Berlin
# Salary     62000
# Name: 2, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df2.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris    7000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# I onlu want to see those people whose age is above 30

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris    7000
# 3  Linda   42  London   85000

# %%
# I onlu want to see those people whose age is above 30 and their city must be paris

# %%
df2[(df2["Age"]>30) & (df2["City"]=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris    7000

# %%
df2[df2["City"]=='Berlin']
# Out:
#     Name  Age    City  Salary
# 2  Peter   29  Berlin   62000
